# %%
import re

# %%
s="cat and mice"

arr=list(s.split())
firstword=arr[0]
vowels=re.findall(r"[aeiou]",firstword)
for i in range(1,len(arr)):
    if (len(re.findall(r"[aeiou]",arr[i]))==len(vowels)):
        arr[i]=arr[i][::-1]
ans=" ".join(arr)
print(ans)
# Out:
# cat dna mice
